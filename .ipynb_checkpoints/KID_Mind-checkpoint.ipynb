# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import torch
import gc
import os
import sys
# %matplotlib notebook
import matplotlib.pyplot as plt

# def printmem():
#     allocated = torch.cuda.memory_allocated()
#     cached = torch.cuda.memory_cached()
#     print('Allocated:', str(allocated), '['+str(round(allocated/1000000000,3))+' GB]')
#     print('   Cached:', str(cached), '['+str(round(cached/1000000000,3))+' GB]')

module_path = os.path.abspath(os.path.join('.'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
    
# printmem()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from criteria import KIDMindLoss
from helpers import Trainer
from helpers import Logger
from helpers import Trial
from mibi_dataloader import KID_Data
from modules import Mind_of_KID
import utils

# printmem()

# %%
# Load the data
main_dir = '/home/hazmat/Documents/projectKID/'
train_dir = main_dir + 'KID_memory/'
# test_dir = main_dir + 'low_AD/'
modl_dir = main_dir + 'models/'
rslt_dir = main_dir + 'results/'

train_ds = KID_Data(folder=train_dir, crop=55, scale=1, stride=1)
# test_ds = MIBIData(folder=test_dir, crop=32, scale=10, stride=16)
# Out:
# finished loading
# There are  10000 samples

# %%
laddernet_args = dict()

# laddernet_args['batchnorm'] = False

kidmind = Mind_of_KID()
# kidmind = Mind_of_KID.load_model('/home/hazmat/Documents/projectKID/models/2019Aug23_01-08-48/', 'model_1599')
kidmind.cuda()

# laddernet.cuda()
# print(owlnet)
# Out:
# Mind_of_KID(
#   (sensory_model): SensoryModel(
#     (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (conv2): Conv2d(8, 16, kernel_size=(5, 5), stride=(2, 2))
#     (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (conv3): Conv2d(16, 32, kernel_size=(5, 5), stride=(2, 2))
#     (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (conv4): Conv2d(32, 32, kernel_size=(5, 5), stride=(2, 2))
#     (bn4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (deconv4): ConvTranspose2d(32, 32, kernel_size=(5, 5), stride=(2, 2))
#     (deconv3): ConvTranspose2d(32, 16, kernel_size=(5, 5), stride=(2, 2))
#     (deconv2): ConvTranspose2d(16, 8, kernel_size=(5, 5), stride=(2, 2))
#     (deconv1): ConvTranspose2d(8, 3, kernel_size=(3, 3), stride=(1, 1))
#     (fc1): Linear(in_features=512, out_features=384, bias=True)
#     (bn5): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc2): Linear(in_features=384, out_features=258, bias=True)
#     (bn6): BatchNorm1d(258, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc3): Linear(in_features=258, out_features=131, bias=True)
#     (bn7): BatchNorm1d(131, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc4): Linear(in_features=131, out_features=3, bias=True)
#     (bn8): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (defc4): Linear(in_features=3, out_features=131, bias=True)
#     (defc3): Linear(in_features=131, out_features=258, bias=True)
#     (defc2): Linear(in_features=258, out_features=384, bias=True)
#     (defc1): Linear(in_features=384, out_features=512, bias=True)
#     (prelu): PReLU(num_parameters=1)
#     (tanh): Tanh()
#   )
#   (perceptual_model): PerceptualModel(
#     (fc1): Linear(in_features=9, out_features=18, bias=True)
#     (bn1): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc2): Linear(in_features=18, out_features=36, bias=True)
#     (bn2): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc3): Linear(in_features=36, out_features=72, bias=True)
#     (bn3): BatchNorm1d(72, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc4): Linear(in_features=72, out_features=9, bias=True)
#     (bn4): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (defc4): Linear(in_features=9, out_features=72, bias=True)
#     (debn4): BatchNorm1d(72, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (defc3): Linear(in_features=72, out_features=36, bias=True)
#     (debn3): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (defc2): Linear(in_features=36, out_features=18, bias=True)
#     (debn2): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (defc1): Linear(in_features=18, out_features=3, bias=True)
#     (prelu): PReLU(num_parameters=1)
#     (tanh): Tanh()
#   )
#   (forward_kinematics_model): ForwardKinematicsModel(
#     (fc1): Linear(in_features=12, out_features=18, bias=True)
#     (bn1): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc2): Linear(in_features=18, out_features=18, bias=True)
#     (bn2): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc3): Linear(in_features=18, out_features=9, bias=True)
#     (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (prelu): PReLU(num_parameters=1)
#     (tanh): Tanh()
#   )
#   (inverse_kinematics_model): InverseKinematicsModel(
#     (fc1): Linear(in_features=19, out_features=36, bias=True)
#     (fc_skip): Linear(in_features=19, out_features=3, bias=True)
#     (bn1): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc2): Linear(in_features=36, out_features=30, bias=True)
#     (bn2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc3): Linear(in_features=30, out_features=20, bias=True)
#     (bn3): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc4): Linear(in_features=20, out_features=10, bias=True)
#     (bn4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc5): Linear(in_features=10, out_features=3, bias=True)
#     (bn5): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#     (fc6): Linear(in_features=3, out_features=3, bias=True)
#     (prelu): PReLU(num_parameters=1)
#     (tanh): Tanh()
#   )
# )

# %%
kidmind_logger = Logger(['loss'])

# %%
kidmind_trainer = Trainer()

# %%
# LadderNet training parameters
kidmind_train_args = dict()
kidmind_train_args['lr'] = 0.001
kidmind_train_args['batch_size'] = 1000
kidmind_train_args['epochs'] = 1000
kidmind_train_args['report'] = 5
kidmind_train_args['crop'] = 55
kidmind_train_args['clip'] = None
kidmind_train_args['decay'] = 0
kidmind_train_args['restart'] = -1
kidmind_train_args['epoch_frac'] = 1
# laddernet_train_args['decay'] = 1e-5

# LadderNet loss parameters
kidmind_loss_args = {
    'alpha': 1, # sensory loss
    'beta': 1, # inverse loss
    'gamma': 1, # forward loss
    'delta': 1 # perceptual loss
}

train_ds.set_crop(kidmind_train_args['crop'])

# %%
kidmind_train_args['continue'] = False
kidmind.set_noise_level(0)
kidmind_criterion = KIDMindLoss(**kidmind_loss_args)
kidmind_trainer.train(kidmind, train_ds, kidmind_criterion, kidmind_logger, '/home/hazmat/Documents/projectKID/models/', **kidmind_train_args)
# Out:
# Epoch:2000 > < 0.005156758137875133
# Epoch:2001 > < 0.005520395520660613
# Epoch:2002 > < 0.006136942499627669
# Epoch:2003 > < 0.005014295638021495
# Epoch:2004 > < 0.005475095421489742
# Epoch:2005 > < 0.005652046193265253
# Epoch:2006 > < 0.004917606840737992
# Epoch:2007 > < 0.004349504804445637
# Epoch:2008 > < 0.004554839830638634
# Epoch:2009 > < 0.005383533425629139
# Epoch:2010 > < 0.005354313438551294
# Epoch:2011 > < 0.005163454062615831
# Epoch:2012 > < 0.005173389903373188
# Epoch:2013 > < 0.005010307999327779
# Epoch:2014 > < 0.004784454436351855
# Epoch:2015 > < 0.005805987890602814
# Epoch:2016 > < 0.00516965545506941
# Epoch:2017 > < 0.005289774388074875
# Epoch:2018 > < 0.005383373807287878
# Epoch:2019 > < 0.005023390209923188
# Epoch:2020 > < 0.004774210560652945
# Epoch:2021 > < 0.0048010040126327015
# Epoch:2022 > < 0.00463108118209574
# Epoch:2023 > < 0.005259305445684327
# Epoch:2024 > < 0.004609552651850713
# Epoch:2025 > < 0.004882621553002132
# Epoch:2026 > < 0.004549985001277592
# Epoch:2027 > < 0.004706191390545832
# Epoch:2028 > < 0.005422297244270642
# Epoch:2029 > < 0.004159215475536055
# Epoch:2030 > < 0.005140475566602415
# Epoch:2031 > < 0.00533561273995373
# Epoch:2032 > < 0.00523069164612227
# Epoch:2033 > < 0.0053011587717466885
# Epoch:2034 > < 0.00491905659954581
# Epoch:2035 > < 0.0049390358488178914
# Epoch:2036 > < 0.005187611095607281
# Epoch:2037 > < 0.005240837370769845
# Epoch:2038 > < 0.005112980337192615
# Epoch:2039 > < 0.0044990897747791475
# Epoch:2040 > < 0.005098192331691583
# Epoch:2041 > < 0.0050396794815444285
# Epoch:2042 > < 0.005425071498999993
# Epoch:2043 > < 0.005978679180973106
# Epoch:2044 > < 0.005134211490965552
# Epoch:2045 > < 0.005259218858554959
# Epoch:2046 > < 0.004611896920121378
# Epoch:2047 > < 0.005076643648660845
# Epoch:2048 > < 0.005565339544167121
# Epoch:2049 > < 0.005133498615274827
# Epoch:2050 > < 0.005347098715396391
# Epoch:2051 > < 0.004904343643122249
# Epoch:2052 > < 0.005377880685652296
# Epoch:2053 > < 0.00467295768774218
# Epoch:2054 > < 0.005072900378662679
# Epoch:2055 > < 0.004565223559944166
# Epoch:2056 > < 0.0049539791523582405
# Epoch:2057 > < 0.0048875033389776945
# Epoch:2058 > < 0.0046460631355229355
# Epoch:2059 > < 0.005123325571831729
# Epoch:2060 > < 0.005079165049311187
# Epoch:2061 > < 0.004928395074481766
# Epoch:2062 > < 0.005704241597818004
# Epoch:2063 > < 0.005658618277973599
# Epoch:2064 > < 0.00538985032795204
# Epoch:2065 > < 0.005451459489348862
# Epoch:2066 > < 0.006095634825113747
# Epoch:2067 > < 0.0055288887168798186
# Epoch:2068 > < 0.005137789166635937
# Epoch:2069 > < 0.004865606315433979
# Epoch:2070 > < 0.004729170222870178
# Epoch:2071 > < 0.0040319077929274905
# Epoch:2072 > < 0.004445095339583026
# Epoch:2073 > < 0.005155855634560187
# Epoch:2074 > < 0.005226621818211343
# Epoch:2075 > < 0.004517661847381128
# Epoch:2076 > < 0.004830264589852757
# Epoch:2077 > < 0.004611406837486559
# Epoch:2078 > < 0.004771941677770681
# Epoch:2079 > < 0.005157251712969608
# Epoch:2080 > < 0.005301623243010706
# Epoch:2081 > < 0.005473629778458012
# Epoch:2082 > < 0.005067784753110673
# Epoch:2083 > < 0.005236605492730935
# Epoch:2084 > < 0.005083992715097136
# Epoch:2085 > < 0.005446368931896157
# Epoch:2086 > < 0.004784202073804206
# Epoch:2087 > < 0.005041153273648686
# Epoch:2088 > < 0.005331870013227065
# Epoch:2089 > < 0.005564502388652828
# Epoch:2090 > < 0.005701430245406098
# Epoch:2091 > < 0.0059807382834454375
# Epoch:2092 > < 0.005627492649687661
# Epoch:2093 > < 0.005162773602124717
# Epoch:2094 > < 0.005259714813696014
# Epoch:2095 > < 0.005181953595537279
# Epoch:2096 > < 0.005486195182634724
# Epoch:2097 > < 0.00501502946847015
# Epoch:2098 > < 0.004902222012687061
# Epoch:2099 > < 0.004833141186585029
# Epoch:2100 > < 0.004576082289632823
# Epoch:2101 > < 0.005721712562566002
# Epoch:2102 > < 0.004861760988003678
# Epoch:2103 > < 0.004994591749790642
# Epoch:2104 > < 0.00503810200219353
# Epoch:2105 > < 0.00513450835003621
# Epoch:2106 > < 0.0044629791130622225
# Epoch:2107 > < 0.004840851347479556
# Epoch:2108 > < 0.0043459854399164515
# Epoch:2109 > < 0.004848530334937904
# Epoch:2110 > < 0.005182746590839492
# Epoch:2111 > < 0.004774232446733449
# Epoch:2112 > < 0.004793298974012335
# Epoch:2113 > < 0.004613876756694581
# Epoch:2114 > < 0.00497445407220059
# Epoch:2115 > < 0.00523087496144904
# Epoch:2116 > < 0.004738854761752818
# Epoch:2117 > < 0.005790254618558619
# Epoch:2118 > < 0.004997012334772282
# Epoch:2119 > < 0.00549316320878764
# Epoch:2120 > < 0.0045718958135694265
# Epoch:2121 > < 0.004496251750323508
# Epoch:2122 > < 0.004755267925146554
# Epoch:2123 > < 0.004605779346699516
# Epoch:2124 > < 0.0048841922802643645
# Epoch:2125 > < 0.004890763925181495
# Epoch:2126 > < 0.0048138962334228885
# Epoch:2127 > < 0.004621820808905695
# Epoch:2128 > < 0.004581009115402897
# Epoch:2129 > < 0.004917876432753271
# Epoch:2130 > < 0.004794356257965167
# Epoch:2131 > < 0.005103766711221801
# Epoch:2132 > < 0.004321465967223048
# Epoch:2133 > < 0.004799312291045983
# Epoch:2134 > < 0.004889756803297334
# Epoch:2135 > < 0.004770611930224631
# Epoch:2136 > < 0.004570562651173936
# Epoch:2137 > < 0.0056584785795874065
# Epoch:2138 > < 0.004948318987670872
# Epoch:2139 > < 0.005002392792246408
# Epoch:2140 > < 0.004782500495720241
# Epoch:2141 > < 0.004433631353701155
# Epoch:2142 > < 0.004523436435394817
# Epoch:2143 > < 0.005088175750441021
# Epoch:2144 > < 0.004582304171183043
# Epoch:2145 > < 0.004530679977809389
# Epoch:2146 > < 0.005277787775008215
# Epoch:2147 > < 0.005121739219046301
# Epoch:2148 > < 0.004591857885114021
# Epoch:2149 > < 0.004615527344867587
# Epoch:2150 > < 0.0052211483837001854
# Epoch:2151 > < 0.004496879979140229
# Epoch:2152 > < 0.004294707543320126
# Epoch:2153 > < 0.0046842331325428355
# Epoch:2154 > < 0.005071619629032082
# Epoch:2155 > < 0.005090940122803052
# Epoch:2156 > < 0.005290436144504283
# Epoch:2157 > < 0.004920972045511007
# Epoch:2158 > < 0.004762657090193695
# Epoch:2159 > < 0.005593371111899614
# Epoch:2160 > < 0.005386507681881388
# Epoch:2161 > < 0.005378676733622949
# Epoch:2162 > < 0.0044163549318909645
# Epoch:2163 > < 0.005013653956767585
# Epoch:2164 > < 0.004545351904299524
# Epoch:2165 > < 0.004920041499038537
# Epoch:2166 > < 0.0050621057032710975
# Epoch:2167 > < 0.004497478017583489
# Epoch:2168 > < 0.005353059335094359
# Epoch:2169 > < 0.005161045429607232
# Epoch:2170 > < 0.00461771742751201
# Epoch:2171 > < 0.004475555046358042
# Epoch:2172 > < 0.0047727050518410075
# Epoch:2173 > < 0.00478569387147824
# Epoch:2174 > < 0.00456628086976707
# Epoch:2175 > < 0.0044051129888329245
# Epoch:2176 > < 0.004252581158652902
# Epoch:2177 > < 0.004395629486276044
# Epoch:2178 > < 0.004567328659403656
# Epoch:2179 > < 0.004653373629682594
# Epoch:2180 > < 0.005051065236330032
# Epoch:2181 > < 0.004872787019444836
# Epoch:2182 > < 0.005271197555379735
# Epoch:2183 > < 0.00494460921941532
# Epoch:2184 > < 0.004531475715339184
# Epoch:2185 > < 0.004710221921818124
# Epoch:2186 > < 0.004545054838268293
# Epoch:2187 > < 0.004969594275785817
# Epoch:2188 > < 0.005040350395979153
# Epoch:2189 > < 0.005628784238878224
# Epoch:2190 > < 0.004604201919088761
# Epoch:2191 > < 0.004950212987346781
# Epoch:2192 > < 0.005096096959378984
# Epoch:2193 > < 0.005593718184779088
# Epoch:2194 > < 0.0049782859730637735
# Epoch:2195 > < 0.004761929934223493
# Epoch:2196 > < 0.00406536177939011
# Epoch:2197 > < 0.004518277606823378
# Epoch:2198 > < 0.005453523610615068
# Epoch:2199 > < 0.004939620952225394
# Epoch:2200 > < 0.0047760446969833635
# Epoch:2201 > < 0.004459139477047656
# Epoch:2202 > < 0.004508584504947066
# Epoch:2203 > < 0.00434525574867924
# Epoch:2204 > < 0.004634267624674572
# Epoch:2205 > < 0.004633315502562457
# Epoch:2206 > < 0.004693908254719443
# Epoch:2207 > < 0.004281706280178494
# Epoch:2208 > < 0.004507348872721195
# Epoch:2209 > < 0.004543610512175494
# Epoch:2210 > < 0.004057594911298818
# Epoch:2211 > < 0.00424177385866642
# Epoch:2212 > < 0.004543455860887964
# Epoch:2213 > < 0.004352714840529693
# Epoch:2214 > < 0.004327116171932883
# Epoch:2215 > < 0.004513921655921472
# Epoch:2216 > < 0.004157966701313853
# Epoch:2217 > < 0.00462327478453517
# Epoch:2218 > < 0.005200833910041385
# Epoch:2219 > < 0.004628084186050627
# Epoch:2220 > < 0.005382246622401807
# Epoch:2221 > < 0.004175294708046649
# Epoch:2222 > < 0.004427106274912755
# Epoch:2223 > < 0.0046512548966954155
# Epoch:2224 > < 0.004914721292960975
# Epoch:2225 > < 0.004242831556540396
# Epoch:2226 > < 0.004695003541807334
# Epoch:2227 > < 0.005031751287687156
# Epoch:2228 > < 0.00487212391777171
# ...
# Epoch:2924 > < 0.0035646289276580014
# Epoch:2925 > < 0.0043423121484617395
# Epoch:2926 > < 0.0038538604664305844
# Epoch:2927 > < 0.003315603748584787
# Epoch:2928 > < 0.0038699965096182292
# Epoch:2929 > < 0.00377846066839993
# Epoch:2930 > < 0.003402749335186349
# Epoch:2931 > < 0.004456579762821396
# Epoch:2932 > < 0.0036343731141338744
# Epoch:2933 > < 0.00416217056206531
# Epoch:2934 > < 0.0039037755793995326
# Epoch:2935 > < 0.0037511558168464238
# Epoch:2936 > < 0.0034304625716888243
# Epoch:2937 > < 0.0040290803493311005
# Epoch:2938 > < 0.004198936693784263
# Epoch:2939 > < 0.0031372747746192748
# Epoch:2940 > < 0.004020787620296081
# Epoch:2941 > < 0.003659711271110508
# Epoch:2942 > < 0.0032263940148469475
# Epoch:2943 > < 0.003698004332060615
# Epoch:2944 > < 0.003865567941425575
# Epoch:2945 > < 0.0035842154175043106
# Epoch:2946 > < 0.003777322643953893
# Epoch:2947 > < 0.003742810364605652
# Epoch:2948 > < 0.003600747169305881
# Epoch:2949 > < 0.0037853551976796654
# Epoch:2950 > < 0.00297737305259539
# Epoch:2951 > < 0.0034417232188085714
# Epoch:2952 > < 0.004262474106831683
# Epoch:2953 > < 0.0035450600553303957
# Epoch:2954 > < 0.003370241236148609
# Epoch:2955 > < 0.00383152828241388
# Epoch:2956 > < 0.003832024573865864
# Epoch:2957 > < 0.003636941443093949
# Epoch:2958 > < 0.003480635661010941
# Epoch:2959 > < 0.0033890229339400926
# Epoch:2960 > < 0.003747410322022107
# Epoch:2961 > < 0.003728417679667473
# Epoch:2962 > < 0.003354432423495584
# Epoch:2963 > < 0.004132141436760624
# Epoch:2964 > < 0.0036480464558634493
# Epoch:2965 > < 0.0042708380044334466
# Epoch:2966 > < 0.004019161634561088
# Epoch:2967 > < 0.0032139443016300597
# Epoch:2968 > < 0.0035410661302093
# Epoch:2969 > < 0.003122737139670385
# Epoch:2970 > < 0.004002777186946737
# Epoch:2971 > < 0.0036434711267550788
# Epoch:2972 > < 0.0037776949918932384
# Epoch:2973 > < 0.0036803576577868727
# Epoch:2974 > < 0.003946460498910811
# Epoch:2975 > < 0.003332873599396812
# Epoch:2976 > < 0.003498543027995361
# Epoch:2977 > < 0.0037557583612700305
# Epoch:2978 > < 0.0034548554103821516
# Epoch:2979 > < 0.00360767108698686
# Epoch:2980 > < 0.0038302663144552046
# Epoch:2981 > < 0.003499531807998816
# Epoch:2982 > < 0.003588169114664197
# Epoch:2983 > < 0.00377094688721829
# Epoch:2984 > < 0.0036868700343701574
# Epoch:2985 > < 0.004165060559494628
# Epoch:2986 > < 0.003984937780640191
# Epoch:2987 > < 0.0035870717321005133
# Epoch:2988 > < 0.003890811595030957
# Epoch:2989 > < 0.0034498385050230557
# Epoch:2990 > < 0.0033990644280695254
# Epoch:2991 > < 0.004108173332901465
# Epoch:2992 > < 0.0036788463282088437
# Epoch:2993 > < 0.004148074994898505
# Epoch:2994 > < 0.003485641054188212
# Epoch:2995 > < 0.003688350293992294
# Epoch:2996 > < 0.004087603495766719
# Epoch:2997 > < 0.0035855911102973754
# Epoch:2998 > < 0.004037499169094695
# Epoch:2999 > < 0.003118166881096032
# trained in 4759.944295406342 seconds
# 4759.944295406342

# %%
import numpy as np
import time
kidmind.set_noise_level(0)
kidmind.eval()

idx1 = 20
idx2 = 48

batch1 = train_ds.get_samples([idx1])
batch2 = train_ds.get_samples([idx2])

batch1 = kidmind.forward(**batch1)
batch2 = kidmind.forward(**batch2)

img1 = batch1['~s_i'][0,:,:,:].transpose(0,1).transpose(1,2).detach()
img2 = batch2['~s_i'][0,:,:,:].transpose(0,1).transpose(1,2).detach()

p = batch2['p_i']
print(p)

fig = plt.figure(figsize=[10,5])
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

ax1.imshow(img1.cpu())
ax2.imshow(img2.cpu())
# Out:
# tensor([[ 0.6057,  0.0378, -0.5185,  0.1384,  0.6315,  0.2429, -0.7348,  0.6950,
#           0.9055]], device='cuda:0', grad_fn=<TanhBackward>)
# <img src="data:image/png;base64,..." width="1000">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def run_kid_run(start_state, action_sequence, model):
    action_sequence = clip_actions(action_sequence)
    p_states = list()
    r_states = list()
    s_states = list()
    p_states.append(start_state['p_i'])
    r_states.append(start_state['r_i'])
    s_states.append(start_state['s_i'])
    
    for i in range(len(action_sequence)):
        p_next = kidmind.forward_kinematics_model.forward(p_states[i], action_sequence[i])
        r_next = kidmind.perceptual_model.decode(p_next)
        s_next = kidmind.sensory_model.decode(r_next)
        p_states.append(p_next)
        r_states.append(r_next)
        s_states.append(s_next)
    
    return s_states, r_states, p_states

def calc_loss(target_state, state_sequence, action_sequence):
    mse = torch.nn.MSELoss()
    target_loss = 0
    control_loss = 0
    for i in range(len(action_sequence)):
        control_loss = control_loss + mse(torch.zeros(1,3,device='cuda'), action_sequence[i])
        target_loss = target_loss + mse(target_state, state_sequence[-1])
    loss = target_loss + 0.01*control_loss/len(action_sequence) + 10*mse(target_state, state_sequence[-1])
    return loss

def clip_actions(actions):
    clip_val = 0.05
    for i in range(len(actions)):
        action = actions[i]
        r = torch.norm(action).detach()
        if r > clip_val:
            action = action / r * clip_val
            actions[i] = action
    return actions

# %%
start_batch = train_ds.get_samples([idx1])
target_batch = train_ds.get_samples([idx2])

start = kidmind.forward(**start_batch)
target = kidmind.forward(**target_batch)

N = 5
actions = list()
for i in range(N):
    action = torch.rand(1,3,requires_grad=True, device='cuda')
    # action = 10*(2*action - 1)
    actions.append(action)

# print(actions[0])

# %%
s_states = list()
r_states = list()
p_states = list()

# %%
optimizer = torch.optim.Adam(actions, lr=1)
for i in range(1000):
    optimizer.zero_grad()
    s_states, r_states, p_states = run_kid_run(start, actions, kidmind)
    loss = calc_loss(target['r_i'], r_states, actions)
    loss.backward(retain_graph=True)
    optimizer.step()
    # print(actions)
print(loss)
# print(actions[0])
# Out:
# tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)

# %%
target['r_i']
# Out:
# tensor([[ 0.6590,  0.6492, -0.6481]], device='cuda:0', grad_fn=<TanhBackward>)

# %%
# actions[0] = torch.tensor([[1,-1,0]]).cuda().float()
# actions[1] = torch.tensor([[1,-1,0]]).cuda().float()
s_states, r_states, p_states = run_kid_run(start, actions, kidmind)
for i in range(len(s_states)):
    fig = plt.figure(figsize=[3,3])
    plt.imshow(s_states[i][0,:,:,:].transpose(0,1).transpose(1,2).detach().cpu())
# Out:
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <img src="data:image/png;base64,..." width="300">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">

# %%
# from mpl_toolkits.mplot3d import Axes3D

# import matplotlib.pyplot as plt
# import numpy as np

# fig = plt.figure(figsize=[10,10])
# ax = fig.add_subplot(1, 1, 1, projection='3d')
# ax.scatter(x[:,0], x[:,1], x[:,2], '.')

# %%
actions
# Out:
# [tensor([[-0.0194,  0.0029,  0.0670]], device='cuda:0', requires_grad=True),
#  tensor([[-0.0442,  0.0103,  0.0286]], device='cuda:0', requires_grad=True),
#  tensor([[-0.0066,  0.0063, -0.0077]], device='cuda:0', requires_grad=True),
#  tensor([[ 0.0036, -0.0316, -0.0993]], device='cuda:0', requires_grad=True),
#  tensor([[ 0.0084, -0.0700, -0.1505]], device='cuda:0', requires_grad=True)]

# %%
print(p_states[0])
print(actions[0])
p_next = kidmind.forward_kinematics_model.forward(p_states[0], actions[0])
print('')
print(p_next)
print(p_states[1])
print('')
print(target['r_i'])
print(r_states[-1])

# %%
r_states[1]

# %%
p_states[2]

# %%
print('start: ', p_states[0])
print('action:', actions[0])
p_next = kidmind.forward_kinematics_model.forward(p_states[0], actions[0])
print('')
print(p_next)
for i in range(len(p_states)):
    print(p_states[i])

# %%
import numpy as np
batch = train_ds.get_samples(np.random.permutation(1000))
s_states = batch['s_i']
r_states, pre_r_states = kidmind.sensory_model.encode(s_states)

# %%
data = pre_r_states[:,0].cpu().detach().numpy()
# print(data)
hist = np.histogram(data)

# %%
torch.mean(r_states,0)

# %%
torch.std(r_states,0)

# %%
torch.sqrt(kidmind.sensory_model.bn8.running_var)

# %%
fig = plt.figure()
plt.hist(data, bins=1000)
print(torch.std(torch.tensor(data)))
